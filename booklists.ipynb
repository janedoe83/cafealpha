# %% [markdown]
# ## Children of Time
#
# :::: {.columns}
#
# ::: {.column width="25%"}
# ![](../img/book_children_of_time.jpg){width=100}
# ::::
#
# ::: {.column width="75%"}
# **Author**: Adrian Tchaikovsky \
# **Year**: 2015 \
# **Genre**: Science Fiction
# ::::
